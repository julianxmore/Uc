 503, 594, 506, 597, 1562, 595, 1562, 595, 1565, 598, 1561, 573, 1585, 601, 1563, 595, 1567, 598, 1562, 595, 511, 592, 510, 570, 1590, 594, 1568, 590, 1570, 568, 534, 566, 538, 587, 514, 563, 1595, 565, 1596, 565, 537, 589, 511, 568, 535, 564, 1595, 568, 1592, 561, 1599, 561, 38227, 8932, 2149, 563,6717725, 8993, 4284, 600, 502, 592, 508, 565, 537, 563, 540, 566, 536, 567, 536, 567, 538, 566, 537, 569, 1592, 603, 1558, 596, 1565, 608, 1556, 604, 1557, 600, 1561, 600, 1564, 597, 1561, 596, 507, 564, 538, 564, 1597, 606, 1555, 605, 1556, 598, 503, 562, 539, 565, 539, 562, 1598, 606, 1555, 606, 497, 565, 536, 564, 536, 563, 1594, 605, 1557, 595, 1566, 594, 38185, 8957, 2122, 603,37191278, 8977, 4286, 594, 534, 571, 512, 592, 532, 567, 537, 565, 535, 568, 513, 588, 533, 570, 535, 566, 1569, 589, 1570, 591, 1568, 594, 1569, 593, 1569, 594, 1567, 597, 1565, 591, 1571, 591, 512, 569, 535, 592, 1568, 595, 1567, 591, 1571, 590, 513, 590, 513, 590, 512, 592, 1567, 570, 1591, 570, 533, 570, 535, 589, 512, 591, 1568, 589, 1572, 590, 1571, 572, 38218, 8940, 2126, 590]

# Threshold for significant time gap
time_threshold = 200000  # Adjust this threshold as needed

# Function to segment the input data based on time gapsdef segment_input(input_data, time_threshold):
def segment_input(input_data, time_threshold):
    segments = []
    current_segment = []
    for i in range(len(input_data) - 1):
        current_segment.append(input_data[i])
        if input_data[i + 1] - input_data[i] > time_threshold:
            # Eliminar los valores que exceden el umbral de tiempo
            current_segment = [x for x in current_segment if x <= time_threshold]
            if current_segment:  # Añadir solo si la lista no está vacía después de eliminar los valores
                segments.append(current_segment)
            current_segment = []
    # Añadir el último segmento después de verificar el umbral de tiempo
    current_segment.append(input_data[-1])
    current_segment = [x for x in current_segment if x <= time_threshold]
    if current_segment:
        segments.append(current_segment)
    return segments

# Segmentar los datos de entrada
segments = segment_input(input_data, time_threshold)

# Imprimir los segmentos
for i, segment in enumerate(segments):
    print(f"Segmento {i + 1}: {segment}")

# Verificar que todas las sublistas tengan la misma longitud
# Verificar que todas las sublistas tengan la misma longitud
def verify_same_length(segments):
    if not segments:
        print("La lista de segmentos está vacía.")
        return False
    length = len(segments[0])
    for segment in segments:
        if len(segment) != length:
            return False
    return True

# Segmentar los datos de entrada
segments = segment_input(input_data, time_threshold)

# Imprimir los segmentos y el número de datos en cada segmento
for i, segment in enumerate(segments):
    print(f"Segmento {i + 1}: {segment}, Número de datos: {len(segment)}")

# Verificar que todas las sublistas tengan la misma longitud
if verify_same_length(segments):
    print("Todas las sub-listas tienen el mismo número de datos.")
else:
    print("Las sub-listas no tienen el mismo número de datos.")
# Out:
# Segmento 1: [8949, 4291, 590, 534, 565, 537, 566, 536, 563, 516, 586, 512, 590, 514, 588, 535, 567, 536, 569, 1567, 593, 1566, 592, 1568, 593, 1569, 591, 1569, 593, 1568, 594, 1566, 593, 1568, 594, 510, 594, 511, 593, 1565, 594, 1569, 591, 1568, 592, 510, 590, 512, 589, 513, 589, 1570, 565, 1594, 592, 511, 590, 512, 589, 511, 590, 1571, 590, 1570, 591, 1570, 592, 38194, 8955, 2126, 592]
# Segmento 2: [8965, 4287, 573, 560, 567, 537, 593, 512, 574, 533, 574, 509, 594, 513, 597, 535, 567, 535, 569, 1570, 592, 1574, 617, 1545, 592, 1567, 590, 1569, 591, 1569, 590, 1567, 593, 1569, 592, 534, 568, 534, 569, 1567, 593, 1568, 592, 1568, 592, 511, 589, 513, 587, 512, 588, 1569, 591, 1570, 589, 536, 565, 512, 564, 535, 589, 1569, 589, 1568, 589, 1571, 591, 38194, 8967, 2123, 570]
# ...

# %%
import matplotlib.pyplot as plt

def plot(segments):
    plt.rcParams['figure.figsize'] = [20, 3]
    x_val = list(range(len(segments[0])))
    fig, ax = plt.subplots()
    for segment in segments:
        ax.plot(segment)
    plt.xticks(x_val)
    plt.show()

# Llamar a la función plot con los segmentos obtenidos
plot(segments)

# %%
plot([segment[2:66] for segment in segments])

# %%
# Obtener los primeros diez segmentos
first_ten_segments = segments[:10]

# Calcular el promedio para cada posición en los segmentos y crear una lista con todos los promedios
averages = [sum(segment[i] for segment in first_ten_segments) / len(first_ten_segments) for i in range(len(first_ten_segments[0]))]

# Imprimir la lista de promedios
print("Lista con todos los promedios de los primeros diez segmentos:")
print(averages)
# Out:
# Promedio de cada dato en los primeros diez segmentos:
# [8962.1, 4290.8, 589.5, 531.0, 571.1, 527.4, 578.0, 531.9, 569.2, 524.0, 576.5, 527.1, 582.5, 519.4, 587.7, 524.0, 575.2, 528.5, 576.5, 1570.4, 592.9, 1568.3, 593.2, 1567.9, 594.5, 1566.8, 588.3, 1572.0, 591.5, 1570.4, 591.8, 1569.8, 593.7, 1567.5, 588.3, 522.6, 577.1, 526.3, 574.2, 1578.6, 586.6, 1575.0, 588.6, 1572.4, 587.3, 516.0, 583.6, 518.2, 584.0, 518.2, 574.4, 1584.6, 582.6, 1577.9, 583.2, 522.7, 581.5, 518.5, 580.6, 520.5, 584.4, 1575.3, 586.7, 1573.7, 585.5, 1575.6, 581.0, 38204.9, 8932.8, 2137.3, 582.8]
# Lista con todos los datos impares dentro del rango de índices de 2 a 66 de cada segmento:
# ...

# %%
# Obtener los valores impares dentro del rango de índices de 2 a 66 de la lista de promedios
filtered_values = [value for value in averages[2:66] if value % 2 != 0]

# Imprimir la lista de valores impares
print("Lista con todos los datos impares dentro del rango de índices de 2 a 66 de la lista de promedios:")
print(filtered_values)
# Out:
# Lista con todos los datos impares dentro del rango de índices de 2 a 66 de la lista de promedios:
# [589.5, 531.0, 571.1, 527.4, 531.9, 569.2, 576.5, 527.1, 582.5, 519.4, 587.7, 575.2, 528.5, 576.5, 1570.4, 592.9, 1568.3, 593.2, 1567.9, 594.5, 1566.8, 588.3, 591.5, 1570.4, 591.8, 1569.8, 593.7, 1567.5, 588.3, 522.6, 577.1, 526.3, 574.2, 1578.6, 586.6, 1575.0, 588.6, 1572.4, 587.3, 583.6, 518.2, 518.2, 574.4, 1584.6, 582.6, 1577.9, 583.2, 522.7, 581.5, 518.5, 580.6, 520.5, 584.4, 1575.3, 586.7, 1573.7, 585.5, 1575.6]

# %%
binario=[('1' if filtered_values[i] > 1000 else '0')  for i in range(32) ]
binario=''.join(binario)
binario
# Out:
# '00000000000000101010100101010000'

# %%
cod=[int(binario[i*8 : (i+1)*8],2)  for i in range(4)]
cod
# Out:
# [0, 2, 169, 80]

# %%
[hex(val) for val in cod]
# Out:
# ['0x0', '0x2', '0xa9', '0x50']

# %% [markdown]
# # Cristian Barragan (20211005074)
#
#
# # Elvis Salazar(20202005022)
#
#
# # Julian Moreno (20201005114)
#
#
# # Numero 5
